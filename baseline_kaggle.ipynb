# %%
import warnings

import pandas as pd

from config import KAGGLE_DATA_PATH, KAGGLE_TARGET
from data_preprocessing import load_datasets
from oversampling import OversamplingTechniques

from eval import evaluate_models
from plotting import plot_results
from utils import load_from_pickle, save_to_pickle

warnings.simplefilter(action="ignore")

data_path = KAGGLE_DATA_PATH
datasets = load_datasets(
    data_path,
    [],
    KAGGLE_TARGET,
    oversampling=OversamplingTechniques.SMOTE,
)

# %%
use_overall_performance_cache = False
if use_overall_performance_cache:
    overall_performance = load_from_pickle("results/overall_performance_kaggle.pkl")
else:
    overall_performance = evaluate_models(datasets, KAGGLE_TARGET)

save_to_pickle(overall_performance, "results/overall_performance_kaggle.pkl")
overall_performance
# Out:
# Processing data for dataset...
#   Training RandomForest...

# %%
plot_results(overall_performance)

# %%
for course_name, course_performance in overall_performance.items():
    print(f"Performance Metrics for {course_name}")

    data = []
    # loop over each classifier and its performance metrics
    for clf_name, clf_performance in course_performance.items():
        row = {"Classifier": clf_name}

        metrics = clf_performance["performance"]
        best_params = clf_performance.get("best_params", {})
        row["Best Params"] = str(best_params)

        row.update(
            metrics
        )  # add 'AUC', 'F1', 'Accuracy' keys and their values to each row

        data.append(row)

    df_metrics = pd.DataFrame(data)
    print(df_metrics)
    print("\n" + "=" * 50 + "\n")
    df_metrics.to_csv(f"results/{course_name}_performance_metrics.csv", index=False)
# Out:
# Performance Metrics for 110
#                   Classifier  \
# 0               RandomForest
# 1         K-nearest-neighbor
# 2  Artificial Neural Network
# 3              Decision Tree
# 4        Logistic Regression
# 5     Support Vector Machine
# 6                Naive Bayes
# 7                   XG-boost
#
#                                          Best Params  accuracy  f1_score  \
# 0  {'bootstrap': False, 'max_depth': 5, 'max_feat...  0.966667  0.966554
# 1  {'leaf_size': 30, 'n_neighbors': 5, 'weights':...  0.933333  0.932730
# 2  {'activation': 'relu', 'hidden_layer_sizes': (...  0.966667  0.966554
# 3          {'criterion': 'gini', 'splitter': 'best'}  0.866667  0.862963
# 4  {'C': 0.5, 'penalty': 'l1', 'solver': 'libline...  0.866667  0.866667
# 5     {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}  0.966667  0.966554
# 6                                                 {}  0.800000  0.794570
# 7  {'learning_rate': 0.01, 'n_estimators': 50, 'o...  0.966667  0.966554
#
#     roc_auc
# 0  0.964286
# 1  0.928571
# 2  0.964286
# 3  0.857143
# 4  0.870536
# 5  0.964286
# 6  0.812500
# 7  0.964286
#
# ==================================================
#
# Performance Metrics for 111
#                   Classifier  \
# 0               RandomForest
# 1         K-nearest-neighbor
# 2  Artificial Neural Network
# 3              Decision Tree
# 4        Logistic Regression
# 5     Support Vector Machine
# 6                Naive Bayes
# 7                   XG-boost
#
#                                          Best Params  accuracy  f1_score  \
# 0  {'bootstrap': True, 'max_depth': 8, 'max_featu...       1.0  1.000000
# 1  {'leaf_size': 30, 'n_neighbors': 5, 'weights':...       0.8  0.780952
# 2  {'activation': 'tanh', 'hidden_layer_sizes': (...       0.8  0.800000
# 3     {'criterion': 'entropy', 'splitter': 'random'}       0.4  0.400000
# 4  {'C': 0.5, 'penalty': 'l1', 'solver': 'libline...       0.6  0.566667
# 5   {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}       0.6  0.566667
# 6                                                 {}       0.6  0.566667
# 7  {'learning_rate': 0.01, 'n_estimators': 50, 'o...       1.0  1.000000
#
#     roc_auc
# 0  1.000000
# 1  0.750000
# 2  0.833333
# 3  0.416667
# 4  0.666667
# 5  0.666667
# 6  0.666667
# 7  1.000000
#
# ==================================================
#
# Performance Metrics for 218
#                   Classifier  \
# 0               RandomForest
# 1         K-nearest-neighbor
# 2  Artificial Neural Network
# 3              Decision Tree
# 4        Logistic Regression
# 5     Support Vector Machine
# 6                Naive Bayes
# 7                   XG-boost
#
#                                          Best Params  accuracy  f1_score  \
# 0  {'bootstrap': False, 'max_depth': 8, 'max_feat...  0.757576  0.755297
# 1  {'leaf_size': 30, 'n_neighbors': 2, 'weights':...  0.787879  0.787088
# 2  {'activation': 'relu', 'hidden_layer_sizes': (...  0.787879  0.788270
# 3        {'criterion': 'gini', 'splitter': 'random'}  0.757576  0.755297
# 4  {'C': 1.5, 'penalty': 'l2', 'solver': 'libline...  0.818182  0.817513
# 5        {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}  0.787879  0.788270
# 6                                                 {}  0.787879  0.788270
# 7  {'learning_rate': 0.01, 'n_estimators': 50, 'o...  0.787879  0.784253
#
#     roc_auc
# 0  0.750000
# 1  0.783333
# 2  0.788889
# 3  0.750000
# 4  0.827778
# 5  0.788889
# 6  0.788889
# 7  0.777778
#
# ==================================================
#
# Performance Metrics for 29
#                   Classifier  \
# 0               RandomForest
# 1         K-nearest-neighbor
# 2  Artificial Neural Network
# 3              Decision Tree
# 4        Logistic Regression
# 5     Support Vector Machine
# 6                Naive Bayes
# 7                   XG-boost
#
#                                          Best Params  accuracy  f1_score  \
# 0  {'bootstrap': True, 'max_depth': 5, 'max_featu...  0.782609  0.782059
# 1  {'leaf_size': 30, 'n_neighbors': 2, 'weights':...  0.768116  0.767137
# 2  {'activation': 'relu', 'hidden_layer_sizes': (...  0.797101  0.797101
# 3          {'criterion': 'gini', 'splitter': 'best'}  0.753623  0.753000
# 4  {'C': 0.5, 'penalty': 'l2', 'solver': 'libline...  0.652174  0.642279
# 5       {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}  0.739130  0.738472
# 6                                                 {}  0.449275  0.395733
# 7  {'learning_rate': 0.1, 'n_estimators': 50, 'ob...  0.811594  0.811515
#
#     roc_auc
# 0  0.781933
# 1  0.767227
# 2  0.797059
# 3  0.752941
# 4  0.654622
# 5  0.739916
# 6  0.444958
# 7  0.811345
#
# ==================================================
#
# Performance Metrics for 46
#                   Classifier  \
# 0               RandomForest
# 1         K-nearest-neighbor
# 2  Artificial Neural Network
# 3              Decision Tree
# 4        Logistic Regression
# 5     Support Vector Machine
# 6                Naive Bayes
# 7                   XG-boost
#
#                                          Best Params  accuracy  f1_score  \
# 0  {'bootstrap': False, 'max_depth': 5, 'max_feat...       1.0  1.000000
# 1  {'leaf_size': 30, 'n_neighbors': 2, 'weights':...       0.6  0.450000
# 2  {'activation': 'tanh', 'hidden_layer_sizes': (...       0.6  0.450000
# 3     {'criterion': 'entropy', 'splitter': 'random'}       0.8  0.800000
# 4  {'C': 0.5, 'penalty': 'l2', 'solver': 'libline...       0.6  0.450000
# 5        {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}       0.6  0.450000
# 6                                                 {}       0.6  0.450000
# 7  {'learning_rate': 0.01, 'n_estimators': 50, 'o...       0.4  0.228571
#
#     roc_auc
# 0  1.000000
# 1  0.500000
# 2  0.500000
# 3  0.833333
# 4  0.500000
# 5  0.500000
# 6  0.500000
# 7  0.500000
#
# ==================================================
#
# Performance Metrics for 88
#                   Classifier  \
# 0               RandomForest
# 1         K-nearest-neighbor
# 2  Artificial Neural Network
# 3              Decision Tree
# 4        Logistic Regression
# 5     Support Vector Machine
# 6                Naive Bayes
# 7                   XG-boost
#
#                                          Best Params  accuracy  f1_score  \
# 0  {'bootstrap': False, 'max_depth': 10, 'max_fea...  0.666667  0.665747
# 1  {'leaf_size': 30, 'n_neighbors': 5, 'weights':...  0.592593  0.592593
# 2  {'activation': 'tanh', 'hidden_layer_sizes': (...  0.592593  0.592593
# 3        {'criterion': 'gini', 'splitter': 'random'}  0.555556  0.548148
# 4  {'C': 0.5, 'penalty': 'l2', 'solver': 'libline...  0.518519  0.517190
# 5         {'C': 1, 'gamma': 'auto', 'kernel': 'rbf'}  0.666667  0.661057
# 6                                                 {}  0.814815  0.809620
# 7  {'learning_rate': 0.01, 'n_estimators': 50, 'o...  0.518519  0.514534
#
#     roc_auc
# 0  0.664835
# 1  0.593407
# 2  0.593407
# 3  0.560440
# 4  0.516484
# 5  0.662088
# 6  0.821429
# 7  0.521978
#
# ==================================================
#
# Performance Metrics for 94
#                   Classifier  \
# 0               RandomForest
# 1         K-nearest-neighbor
# 2  Artificial Neural Network
# 3              Decision Tree
# 4        Logistic Regression
# 5     Support Vector Machine
# 6                Naive Bayes
# 7                   XG-boost
#
#                                          Best Params  accuracy  f1_score  \
# 0  {'bootstrap': True, 'max_depth': 5, 'max_featu...  0.695652  0.702771
# 1  {'leaf_size': 30, 'n_neighbors': 5, 'weights':...  0.652174  0.660201
# 2  {'activation': 'relu', 'hidden_layer_sizes': (...  0.695652  0.702771
# 3        {'criterion': 'gini', 'splitter': 'random'}  0.608696  0.601964
# 4  {'C': 0.5, 'penalty': 'l1', 'solver': 'libline...  0.782609  0.785254
# 5     {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}  0.652174  0.659075
# 6                                                 {}  0.347826  0.244642
# 7  {'learning_rate': 1.0, 'n_estimators': 100, 'o...  0.695652  0.702771
#
#     roc_auc
# 0  0.708333
# 1  0.675000
# 2  0.708333
# 3  0.554167
# 4  0.775000
# 5  0.645833
# 6  0.470833
# 7  0.708333
#
# ==================================================
